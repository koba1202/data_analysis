# %%
import pandas as pd

df = pd.read_csv("data/Titanic.csv")

y = df["survived"]

features = ['pclass', 'who', 'embarked', 'fare']
x = df[features]

x['who'] = x['who'].replace({'man': 0, 'woman': 1, 'child': 2})
x['embarked'] = x['embarked'].replace({'S': 1, 'C': 2, 'Q': 3})

print(y)
print(x)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64
#      pclass who embarked     fare
# 0         3   0        1   7.2500
# 1         1   1        2  71.2833
# 2         3   1        1   7.9250
# 3         1   1        1  53.1000
# 4         3   0        1   8.0500
# ..      ...  ..      ...      ...
# 886       2   0        1  13.0000
# 887       1   1        1  30.0000
# 888       3   1        1  23.4500
# 889       1   0        2  30.0000
# 890       3   0        3   7.7500
#
# [891 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

print(x_train, y_train)
print(x_test, y_test)
# Out:
#      pclass who embarked      fare
# 331       1   0        1   28.5000
# 733       2   0        1   13.0000
# 382       3   0        1    7.9250
# 704       3   0        1    7.8542
# 813       3   2        1   31.2750
# ..      ...  ..      ...       ...
# 106       3   1        1    7.6500
# 270       1   0        1   31.0000
# 860       3   0        1   14.1083
# 435       1   2        1  120.0000
# 102       1   0        1   77.2875
#
# [712 rows x 4 columns] 331    0
# 733    0
# 382    0
# 704    0
# 813    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: survived, Length: 712, dtype: int64
#      pclass who embarked     fare
# 709       3   0        2  15.2458
# 439       2   0        1  10.5000
# 840       3   0        1   7.9250
# 720       2   2        1  33.0000
# 39        3   2        2  11.2417
# ..      ...  ..      ...      ...
# 433       3   0        1   7.1250
# 773       3   0        2   7.2250
# 25        3   1        1  31.3875
# 84        2   1        1  10.5000
# 10        3   2        1  16.7000
#
# [179 rows x 4 columns] 709    1
# 439    0
# 840    0
# 720    1
# 39     1
#       ..
# 433    0
# 773    0
# 25     1
# 84     1
# 10     1
# Name: survived, Length: 179, dtype: int64
